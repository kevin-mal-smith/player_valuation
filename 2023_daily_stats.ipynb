# %%
# i am going to hit the mmlb stats api for daily stats and build predictive models based on the results
import pandas as pd
import statsapi
import regex
import datetime

# %%
schedule_to_date = pd.DataFrame(statsapi.schedule(start_date = '2023-03-30', end_date = '2023-07-11'))

# %%
list_of_teams = schedule_to_date.home_id.unique().tolist()

# %%
rangers_games=schedule_to_date.game_id[(schedule_to_date.home_id ==140)|(schedule_to_date.away_id == 140)].to_list()

# %%
len(rangers_games)-1
# Out:
# 90

# %%
rangers = []
for i in range(len(rangers_games)-1):
    rangers.append(statsapi.boxscore_data(rangers_games[i]))

# %%
rangers = pd.DataFrame(rangers)

# %%
rangers_hitting = pd.DataFrame(rangers['homeBatters'])

# %%
rangers['homeBatters'][0]
# Out:
# [{'namefield': 'Rangers Batters',
#   'ab': 'AB',
#   'r': 'R',
#   'h': 'H',
#   'doubles': '2B',
#   'triples': '3B',
#   'hr': 'HR',
#   'rbi': 'RBI',
#   'sb': 'SB',
#   'bb': 'BB',
#   'k': 'K',
#   'lob': 'LOB',
#   'avg': 'AVG',
#   'ops': 'OPS',
#   'personId': 0,
#   'substitution': False,
#   'note': '',
#   'name': 'Rangers Batters',
#   'position': '',
#   'obp': 'OBP',
#   'slg': 'SLG',
#   'battingOrder': ''},
#  {'namefield': '1 Semien  2B',
#   'ab': '5',
#   'r': '1',
#   'h': '2',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '0',
#   'sb': '1',
#   'bb': '0',
#   'k': '1',
#   'lob': '0',
#   'avg': '.400',
#   'ops': '.800',
#   'personId': 543760,
#   'battingOrder': '100',
#   'substitution': False,
#   'note': '',
#   'name': 'Semien',
#   'position': '2B',
#   'obp': '.400',
#   'slg': '.400'},
#  {'namefield': '2 Seager  SS',
#   'ab': '3',
#   'r': '2',
#   'h': '1',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '0',
# ...

# %%
rangers
# Out:
#                         gameId  \
# 0   2023/03/30/phimlb-texmlb-1
# 1   2023/04/01/phimlb-texmlb-1
# 2   2023/04/02/phimlb-texmlb-1
# 3   2023/04/03/balmlb-texmlb-1
# 4   2023/04/04/balmlb-texmlb-1
# ..                         ...
# 85  2023/07/04/texmlb-bosmlb-1
# 86  2023/07/05/texmlb-bosmlb-1
# 87  2023/07/06/texmlb-bosmlb-1
# 88  2023/07/07/texmlb-wasmlb-1
# 89  2023/07/08/texmlb-wasmlb-1
#
#                                              teamInfo  \
# 0   {'away': {'id': 143, 'abbreviation': 'PHI', 't...
# 1   {'away': {'id': 143, 'abbreviation': 'PHI', 't...
# 2   {'away': {'id': 143, 'abbreviation': 'PHI', 't...
# 3   {'away': {'id': 110, 'abbreviation': 'BAL', 't...
# 4   {'away': {'id': 110, 'abbreviation': 'BAL', 't...
# ..                                                ...
# 85  {'away': {'id': 140, 'abbreviation': 'TEX', 't...
# 86  {'away': {'id': 140, 'abbreviation': 'TEX', 't...
# 87  {'away': {'id': 140, 'abbreviation': 'TEX', 't...
# ...

# %%
schedule_to_date[schedule_to_date.venue_name=='Yankee Stadium'].T
# Out:
#                                                                     1     \
# game_id                                                           718781
# game_datetime                                       2023-03-30T17:05:00Z
# game_date                                                     2023-03-30
# game_type                                                              R
# status                                                             Final
# away_name                                           San Francisco Giants
# home_name                                               New York Yankees
# away_id                                                              137
# home_id                                                              147
# doubleheader                                                           N
# game_num                                                               1
# home_probable_pitcher                                        Gerrit Cole
# ...

# %%
statsapi.game_pace_data(season=2022)
# Out:
# {'copyright': 'Copyright 2023 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'teams': [],
#  'leagues': [],
#  'sports': [{'hitsPer9Inn': 16.58,
#    'runsPer9Inn': 8.7,
#    'pitchesPer9Inn': 296.08,
#    'plateAppearancesPer9Inn': 76.07,
#    'hitsPerGame': 16.33,
#    'runsPerGame': 8.57,
#    'inningsPlayedPerGame': 8.89,
#    'pitchesPerGame': 291.58,
#    'pitchersPerGame': 8.59,
#    'plateAppearancesPerGame': 74.92,
#    'totalGameTime': '7558:45:59',
#    'totalInningsPlayed': 21604.0,
#    'totalHits': 39674,
#    'totalRuns': 20817,
#    'totalPlateAppearances': 182052,
#    'totalPitchers': 20883,
#    'totalPitches': 708540,
#    'totalGames': 2430,
#    'total7InnGames': 10,
#    'total9InnGames': 2204,
#    'totalExtraInnGames': 216,
#    'timePerGame': '03:06:38',
#    'timePerPitch': '00:00:38',
#    'timePerHit': '00:11:25',
#    'timePerRun': '00:21:47',
# ...

# %%
statsapi.game_pace_data(season=2023)
# Out:
# {'copyright': 'Copyright 2023 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'teams': [],
#  'leagues': [],
#  'sports': [{'hitsPer9Inn': 17.03,
#    'runsPer9Inn': 9.28,
#    'pitchesPer9Inn': 299.31,
#    'plateAppearancesPer9Inn': 76.82,
#    'hitsPerGame': 16.78,
#    'runsPerGame': 9.14,
#    'inningsPlayedPerGame': 8.89,
#    'pitchesPerGame': 294.81,
#    'pitchersPerGame': 8.41,
#    'plateAppearancesPerGame': 75.67,
#    'totalGameTime': '3628:54:59',
#    'totalInningsPlayed': 12063.5,
#    'totalHits': 22764,
#    'totalRuns': 12402,
#    'totalPlateAppearances': 102683,
#    'totalPitchers': 11415,
#    'totalPitches': 400060,
#    'totalGames': 1357,
#    'total7InnGames': 1,
#    'total9InnGames': 1243,
#    'totalExtraInnGames': 113,
#    'timePerGame': '02:40:27',
#    'timePerPitch': '00:00:32',
#    'timePerHit': '00:09:33',
#    'timePerRun': '00:17:33',
# ...

# %%
pace = statsapi.get('gamePace',{'season':2023})

# %%
pace
# Out:
# {'copyright': 'Copyright 2023 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'teams': [],
#  'leagues': [],
#  'sports': [{'hitsPer9Inn': 17.03,
#    'runsPer9Inn': 9.28,
#    'pitchesPer9Inn': 299.31,
#    'plateAppearancesPer9Inn': 76.82,
#    'hitsPerGame': 16.78,
#    'runsPerGame': 9.14,
#    'inningsPlayedPerGame': 8.89,
#    'pitchesPerGame': 294.81,
#    'pitchersPerGame': 8.41,
#    'plateAppearancesPerGame': 75.67,
#    'totalGameTime': '3628:54:59',
#    'totalInningsPlayed': 12063.5,
#    'totalHits': 22764,
#    'totalRuns': 12402,
#    'totalPlateAppearances': 102683,
#    'totalPitchers': 11415,
#    'totalPitches': 400060,
#    'totalGames': 1357,
#    'total7InnGames': 1,
#    'total9InnGames': 1243,
#    'totalExtraInnGames': 113,
#    'timePerGame': '02:40:27',
#    'timePerPitch': '00:00:32',
#    'timePerHit': '00:09:33',
#    'timePerRun': '00:17:33',
# ...

# %%
statsapi.get('gamePace',{'teamIds':140,'season':2023})['teams'][0]
# Out:
# {'hitsPer9Inn': 18.2,
#  'runsPer9Inn': 11.02,
#  'pitchesPer9Inn': 304.75,
#  'plateAppearancesPer9Inn': 78.05,
#  'hitsPerGame': 17.8,
#  'runsPerGame': 10.78,
#  'inningsPlayedPerGame': 8.81,
#  'pitchesPerGame': 297.98,
#  'pitchersPerGame': 8.27,
#  'plateAppearancesPerGame': 76.31,
#  'totalGameTime': '119:43:00',
#  'totalInningsPlayed': 396.5,
#  'totalHits': 801,
#  'totalRuns': 485,
#  'totalPlateAppearances': 3434,
#  'totalPitchers': 372,
#  'totalPitches': 13409,
#  'totalGames': 45,
#  'total9InnGames': 43,
#  'totalExtraInnGames': 2,
#  'timePerGame': '02:39:37',
#  'timePerPitch': '00:00:32',
#  'timePerHit': '00:08:58',
#  'timePerRun': '00:14:48',
#  'timePerPlateAppearance': '00:02:05',
#  'timePer9Inn': '02:43:14',
#  'timePer77PlateAppearances': '02:41:03',
#  'totalExtraInnTime': '06:40:00',
#  'timePer7InnGameWithoutExtraInn': '00:00:00',
#  'total9InnGamesWithoutExtraInn': 43,
#  'total9InnGamesScheduled': 45,
#  'hitsPerRun': 1.652,
# ...

# %%
statsapi.game_pace_data(2023)
# Out:
# {'copyright': 'Copyright 2023 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'teams': [],
#  'leagues': [],
#  'sports': [{'hitsPer9Inn': 17.03,
#    'runsPer9Inn': 9.28,
#    'pitchesPer9Inn': 299.31,
#    'plateAppearancesPer9Inn': 76.82,
#    'hitsPerGame': 16.78,
#    'runsPerGame': 9.14,
#    'inningsPlayedPerGame': 8.89,
#    'pitchesPerGame': 294.81,
#    'pitchersPerGame': 8.41,
#    'plateAppearancesPerGame': 75.67,
#    'totalGameTime': '3628:54:59',
#    'totalInningsPlayed': 12063.5,
#    'totalHits': 22764,
#    'totalRuns': 12402,
#    'totalPlateAppearances': 102683,
#    'totalPitchers': 11415,
#    'totalPitches': 400060,
#    'totalGames': 1357,
#    'total7InnGames': 1,
#    'total9InnGames': 1243,
#    'totalExtraInnGames': 113,
#    'timePerGame': '02:40:27',
#    'timePerPitch': '00:00:32',
#    'timePerHit': '00:09:33',
#    'timePerRun': '00:17:33',
# ...
