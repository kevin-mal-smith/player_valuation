# %%
# !pip install MLB-StatsAPI
# Out:
# Collecting MLB-StatsAPI
#   Downloading MLB_StatsAPI-1.6.1-py3-none-any.whl (30 kB)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from MLB-StatsAPI) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->MLB-StatsAPI) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests->MLB-StatsAPI) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->MLB-StatsAPI) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests->MLB-StatsAPI) (2.0.4)
# Installing collected packages: MLB-StatsAPI
# Successfully installed MLB-StatsAPI-1.6.1

# %%
# i am going to hit the mmlb stats api for daily stats and build predictive models based on the results
import pandas as pd
import statsapi
import regex

# %%
schedule_to_date = pd.DataFrame(statsapi.schedule(start_date = '2023-03-30', end_date = '2023-04-11'))

# %%
schedule_to_date
# Out:
#      game_id         game_datetime   game_date game_type status  \
# 0     718780  2023-03-30T17:05:00Z  2023-03-30         R  Final
# 1     718781  2023-03-30T17:05:00Z  2023-03-30         R  Final
# 2     718782  2023-03-30T18:10:00Z  2023-03-30         R  Final
# 3     718777  2023-03-30T18:20:00Z  2023-03-30         R  Final
# 4     718776  2023-03-30T19:10:00Z  2023-03-30         R  Final
# ..       ...                   ...         ...       ...    ...
# 170   718615  2023-04-12T00:05:00Z  2023-04-11         R  Final
# 171   718613  2023-04-12T00:40:00Z  2023-04-11         R  Final
# 172   718614  2023-04-12T01:38:00Z  2023-04-11         R  Final
# 173   718611  2023-04-12T01:40:00Z  2023-04-11         R  Final
# 174   718624  2023-04-12T01:45:00Z  2023-04-11         R  Final
#
#                 away_name             home_name  away_id  home_id  \
# 0          Atlanta Braves  Washington Nationals      144      120
# 1    San Francisco Giants      New York Yankees      137      147
# 2       Baltimore Orioles        Boston Red Sox      110      111
# 3       Milwaukee Brewers          Chicago Cubs      158      112
# 4          Detroit Tigers        Tampa Bay Rays      116      139
# ..                    ...                   ...      ...      ...
# 170    Kansas City Royals         Texas Rangers      118      140
# 171   St. Louis Cardinals      Colorado Rockies      138      115
# 172  Washington Nationals    Los Angeles Angels      120      108
# 173     Milwaukee Brewers  Arizona Diamondbacks      158      109
# 174   Los Angeles Dodgers  San Francisco Giants      119      137
#
#     doubleheader  ...  venue_id        venue_name national_broadcasts  \
# 0              N  ...      3309    Nationals Park              [MLBN]
# 1              N  ...      3313    Yankee Stadium              [MLBN]
# 2              N  ...         3       Fenway Park  [MLB.tv Free Game]
# 3              N  ...        17     Wrigley Field                  []
# 4              N  ...        12   Tropicana Field                  []
# ..           ...  ...       ...               ...                 ...
# 170            N  ...      5325  Globe Life Field                  []
# 171            N  ...        19       Coors Field                  []
# 172            N  ...         1     Angel Stadium                  []
# 173            N  ...        15       Chase Field              [MLBN]
# 174            N  ...      2395       Oracle Park              [MLBN]
#
#        series_status          winning_team           losing_team  \
# 0      ATL leads 1-0        Atlanta Braves  Washington Nationals
# 1      NYY leads 1-0      New York Yankees  San Francisco Giants
# 2      BAL leads 1-0     Baltimore Orioles        Boston Red Sox
# 3      CHC leads 1-0          Chicago Cubs     Milwaukee Brewers
# 4       TB leads 1-0        Tampa Bay Rays        Detroit Tigers
# ..               ...                   ...                   ...
# 170     TEX wins 2-0         Texas Rangers    Kansas City Royals
# 171  Series tied 1-1   St. Louis Cardinals      Colorado Rockies
# 172  Series tied 1-1    Los Angeles Angels  Washington Nationals
# 173  Series tied 1-1     Milwaukee Brewers  Arizona Diamondbacks
# 174  Series tied 1-1  San Francisco Giants   Los Angeles Dodgers
#
#        winning_pitcher     losing_pitcher    save_pitcher  \
# 0         Lucas Luetge     Patrick Corbin            None
# 1          Gerrit Cole         Logan Webb            None
# 2          Kyle Gibson       Corey Kluber  Felix Bautista
# 3       Marcus Stroman      Corbin Burnes            None
# 4     Shane McClanahan  Eduardo Rodriguez            None
# ..                 ...                ...             ...
# 170        Cole Ragans       Scott Barlow            None
# 171  Giovanny Gallegos     Pierce Johnson    Ryan Helsley
# 172      Shohei Ohtani        Josiah Gray  Carlos Estevez
# 173      Corbin Burnes      Merrill Kelly            None
# 174    Scott Alexander         Dustin May            None
#
#                                                summary
# 0    2023-03-30 - Atlanta Braves (7) @ Washington N...
# 1    2023-03-30 - San Francisco Giants (0) @ New Yo...
# 2    2023-03-30 - Baltimore Orioles (10) @ Boston R...
# 3    2023-03-30 - Milwaukee Brewers (0) @ Chicago C...
# 4    2023-03-30 - Detroit Tigers (0) @ Tampa Bay Ra...
# ..                                                 ...
# 170  2023-04-11 - Kansas City Royals (5) @ Texas Ra...
# 171  2023-04-11 - St. Louis Cardinals (9) @ Colorad...
# 172  2023-04-11 - Washington Nationals (0) @ Los An...
# 173  2023-04-11 - Milwaukee Brewers (7) @ Arizona D...
# 174  2023-04-11 - Los Angeles Dodgers (0) @ San Fra...
#
# [175 rows x 29 columns]

# %%
rangers_games=schedule_to_date.game_id[(schedule_to_date.home_id ==140)|(schedule_to_date.away_id == 140)].to_list()

# %%
# Out:
#          0
# 0   718779
# 1   718752
# 2   718739
# 3   718726
# 4   718709
# 5   718694
# 6   718675
# 7   718669
# 8   718642
# 9   718630
# 10  718615

# %%
len(rangers_games)-1
# Out:
# 10

# %%
rangers = []
for i in range(len(rangers_games)-1):
    rangers.append(statsapi.boxscore_data(rangers_games[i]))

# %%
rangers = pd.DataFrame(rangers)

# %%
rangers_hitting = pd.DataFrame(rangers['homeBatters'])

# %%
rangers['homeBatters'][0]
# Out:
# [{'namefield': 'Rangers Batters',
#   'ab': 'AB',
#   'r': 'R',
#   'h': 'H',
#   'doubles': '2B',
#   'triples': '3B',
#   'hr': 'HR',
#   'rbi': 'RBI',
#   'sb': 'SB',
#   'bb': 'BB',
#   'k': 'K',
#   'lob': 'LOB',
#   'avg': 'AVG',
#   'ops': 'OPS',
#   'personId': 0,
#   'substitution': False,
#   'note': '',
#   'name': 'Rangers Batters',
#   'position': '',
#   'obp': 'OBP',
#   'slg': 'SLG',
#   'battingOrder': ''},
#  {'namefield': '1 Semien  2B',
#   'ab': '5',
#   'r': '1',
#   'h': '2',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '0',
#   'sb': '1',
#   'bb': '0',
#   'k': '1',
#   'lob': '0',
#   'avg': '.400',
#   'ops': '.800',
#   'personId': 543760,
#   'battingOrder': '100',
#   'substitution': False,
#   'note': '',
#   'name': 'Semien',
#   'position': '2B',
#   'obp': '.400',
#   'slg': '.400'},
#  {'namefield': '2 Seager  SS',
#   'ab': '3',
#   'r': '2',
#   'h': '1',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '0',
#   'sb': '0',
#   'bb': '2',
#   'k': '0',
#   'lob': '1',
#   'avg': '.333',
#   'ops': '.933',
#   'personId': 608369,
#   'battingOrder': '200',
#   'substitution': False,
#   'note': '',
#   'name': 'Seager',
#   'position': 'SS',
#   'obp': '.600',
#   'slg': '.333'},
#  {'namefield': '3 Lowe, N  1B',
#   'ab': '3',
#   'r': '1',
#   'h': '1',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '1',
#   'sb': '0',
#   'bb': '1',
#   'k': '0',
#   'lob': '2',
#   'avg': '.333',
#   'ops': '.833',
#   'personId': 663993,
#   'battingOrder': '300',
#   'substitution': False,
#   'note': '',
#   'name': 'Lowe, N',
#   'position': '1B',
#   'obp': '.500',
#   'slg': '.333'},
#  {'namefield': '4 García, Ad  RF',
#   'ab': '4',
#   'r': '1',
#   'h': '2',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '2',
#   'sb': '0',
#   'bb': '0',
#   'k': '1',
#   'lob': '2',
#   'avg': '.500',
#   'ops': '1.000',
#   'personId': 666969,
#   'battingOrder': '400',
#   'substitution': False,
#   'note': '',
#   'name': 'García, Ad',
#   'position': 'RF',
#   'obp': '.500',
#   'slg': '.500'},
#  {'namefield': '5 Jung  3B',
#   'ab': '3',
#   'r': '1',
#   'h': '0',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '0',
#   'sb': '0',
#   'bb': '1',
#   'k': '2',
#   'lob': '0',
#   'avg': '.000',
#   'ops': '.250',
#   'personId': 673962,
#   'battingOrder': '500',
#   'substitution': False,
#   'note': '',
#   'name': 'Jung',
#   'position': '3B',
#   'obp': '.250',
#   'slg': '.000'},
#  {'namefield': '6 Heim  C',
#   'ab': '4',
#   'r': '2',
#   'h': '2',
#   'doubles': '1',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '2',
#   'sb': '0',
#   'bb': '0',
#   'k': '0',
#   'lob': '0',
#   'avg': '.500',
#   'ops': '1.250',
#   'personId': 641680,
#   'battingOrder': '600',
#   'substitution': False,
#   'note': '',
#   'name': 'Heim',
#   'position': 'C',
#   'obp': '.500',
#   'slg': '.750'},
#  {'namefield': '7 Grossman  LF',
#   'ab': '3',
#   'r': '1',
#   'h': '1',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '1',
#   'rbi': '3',
#   'sb': '0',
#   'bb': '1',
#   'k': '1',
#   'lob': '1',
#   'avg': '.333',
#   'ops': '1.833',
#   'personId': 543257,
#   'battingOrder': '700',
#   'substitution': False,
#   'note': '',
#   'name': 'Grossman',
#   'position': 'LF',
#   'obp': '.500',
#   'slg': '1.333'},
#  {'namefield': '8 Miller, B  DH',
#   'ab': '4',
#   'r': '1',
#   'h': '1',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '1',
#   'rbi': '2',
#   'sb': '0',
#   'bb': '0',
#   'k': '2',
#   'lob': '1',
#   'avg': '.250',
#   'ops': '1.250',
#   'personId': 543543,
#   'battingOrder': '800',
#   'substitution': False,
#   'note': '',
#   'name': 'Miller, B',
#   'position': 'DH',
#   'obp': '.250',
#   'slg': '1.000'},
#  {'namefield': '9 Smith, J  LF',
#   'ab': '1',
#   'r': '1',
#   'h': '0',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '0',
#   'sb': '0',
#   'bb': '1',
#   'k': '1',
#   'lob': '0',
#   'avg': '.000',
#   'ops': '.500',
#   'personId': 669701,
#   'battingOrder': '900',
#   'substitution': False,
#   'note': '',
#   'name': 'Smith, J',
#   'position': 'LF',
#   'obp': '.500',
#   'slg': '.000'},
#  {'namefield': '    a-Thompson, B  CF',
#   'ab': '2',
#   'r': '0',
#   'h': '0',
#   'doubles': '0',
#   'triples': '0',
#   'hr': '0',
#   'rbi': '0',
#   'sb': '0',
#   'bb': '0',
#   'k': '0',
#   'lob': '0',
#   'avg': '.000',
#   'ops': '.000',
#   'personId': 669352,
#   'battingOrder': '901',
#   'substitution': True,
#   'note': 'a-',
#   'name': 'Thompson, B',
#   'position': 'CF',
#   'obp': '.000',
#   'slg': '.000'}]

# %%
game_1_df
# Out:
#                                                     person jerseyNumber  \
# ID641680          {'id': 641680, 'fullName': 'Jonah Heim'}           28
# ID666142         {'id': 666142, 'fullName': 'Cole Ragans'}           50
# ID669352      {'id': 669352, 'fullName': 'Bubba Thompson'}            8
# ID453178         {'id': 453178, 'fullName': 'Ian Kennedy'}           21
# ID641540        {'id': 641540, 'fullName': 'Dane Dunning'}           33
# ID663993      {'id': 663993, 'fullName': 'Nathaniel Lowe'}           30
# ID608369        {'id': 608369, 'fullName': 'Corey Seager'}            5
# ID592351            {'id': 592351, 'fullName': 'Jon Gray'}           22
# ID543543         {'id': 543543, 'fullName': 'Brad Miller'}           13
# ID543760       {'id': 543760, 'fullName': 'Marcus Semien'}            2
# ID673962           {'id': 673962, 'fullName': 'Josh Jung'}            6
# ID621368        {'id': 621368, 'fullName': 'Taylor Hearn'}           52
# ID677649      {'id': 677649, 'fullName': 'Ezequiel Duran'}           20
# ID642546  {'id': 642546, 'fullName': 'Jonathan Hernandez'}           72
# ID594798        {'id': 594798, 'fullName': 'Jacob deGrom'}           48
# ID641598        {'id': 641598, 'fullName': 'Mitch Garver'}           18
# ID608671    {'id': 608671, 'fullName': 'Travis Jankowski'}           16
# ID669701       {'id': 669701, 'fullName': 'Josh H. Smith'}           47
# ID571760       {'id': 571760, 'fullName': 'Andrew Heaney'}           44
# ID519293          {'id': 519293, 'fullName': 'Will Smith'}           51
# ID666969       {'id': 666969, 'fullName': 'Adolis Garcia'}           53
# ID656271         {'id': 656271, 'fullName': 'Brock Burke'}           46
# ID543257     {'id': 543257, 'fullName': 'Robbie Grossman'}            4
# ID543135      {'id': 543135, 'fullName': 'Nathan Eovaldi'}           17
# ID600917        {'id': 600917, 'fullName': 'Jose Leclerc'}           25
# ID527048        {'id': 527048, 'fullName': 'Martin Perez'}           54
#
#                         position status parentTeamId battingOrder  \
# ID641680   {'abbreviation': 'C'}     {}          140          600
# ID666142   {'abbreviation': 'P'}     {}          140          NaN
# ID669352  {'abbreviation': 'CF'}     {}          140          901
# ID453178   {'abbreviation': 'P'}     {}          140          NaN
# ID641540   {'abbreviation': 'P'}     {}          140          NaN
# ID663993  {'abbreviation': '1B'}     {}          140          300
# ID608369  {'abbreviation': 'SS'}     {}          140          200
# ID592351   {'abbreviation': 'P'}     {}          140          NaN
# ID543543  {'abbreviation': 'DH'}     {}          140          800
# ID543760  {'abbreviation': '2B'}     {}          140          100
# ID673962  {'abbreviation': '3B'}     {}          140          500
# ID621368   {'abbreviation': 'P'}     {}          140          NaN
# ID677649  {'abbreviation': '3B'}     {}          140          NaN
# ID642546   {'abbreviation': 'P'}     {}          140          NaN
# ID594798   {'abbreviation': 'P'}     {}          140          NaN
# ID641598   {'abbreviation': 'C'}     {}          140          NaN
# ID608671  {'abbreviation': 'LF'}     {}          140          NaN
# ID669701  {'abbreviation': 'LF'}     {}          140          900
# ID571760   {'abbreviation': 'P'}     {}          140          NaN
# ID519293   {'abbreviation': 'P'}     {}          140          NaN
# ID666969  {'abbreviation': 'RF'}     {}          140          400
# ID656271   {'abbreviation': 'P'}     {}          140          NaN
# ID543257  {'abbreviation': 'LF'}     {}          140          700
# ID543135   {'abbreviation': 'P'}     {}          140          NaN
# ID600917   {'abbreviation': 'P'}     {}          140          NaN
# ID527048   {'abbreviation': 'P'}     {}          140          NaN
#
#                                                       stats  \
# ID641680  {'batting': {'runs': 2, 'doubles': 1, 'triples...
# ID666142  {'batting': {}, 'pitching': {'note': '(W, 1-0)...
# ID669352  {'batting': {'note': 'a-', 'runs': 0, 'doubles...
# ID453178                    {'batting': {}, 'pitching': {}}
# ID641540                    {'batting': {}, 'pitching': {}}
# ID663993  {'batting': {'runs': 1, 'doubles': 0, 'triples...
# ID608369  {'batting': {'runs': 2, 'doubles': 0, 'triples...
# ID592351                    {'batting': {}, 'pitching': {}}
# ID543543  {'batting': {'runs': 1, 'doubles': 0, 'triples...
# ID543760  {'batting': {'runs': 1, 'doubles': 0, 'triples...
# ID673962  {'batting': {'runs': 1, 'doubles': 0, 'triples...
# ID621368                    {'batting': {}, 'pitching': {}}
# ID677649                    {'batting': {}, 'pitching': {}}
# ID642546  {'batting': {}, 'pitching': {'runs': 1, 'doubl...
# ID594798  {'batting': {}, 'pitching': {'runs': 5, 'doubl...
# ID641598                    {'batting': {}, 'pitching': {}}
# ID608671                    {'batting': {}, 'pitching': {}}
# ID669701  {'batting': {'runs': 1, 'doubles': 0, 'triples...
# ID571760                    {'batting': {}, 'pitching': {}}
# ID519293                    {'batting': {}, 'pitching': {}}
# ID666969  {'batting': {'runs': 1, 'doubles': 0, 'triples...
# ID656271  {'batting': {}, 'pitching': {'runs': 1, 'doubl...
# ID543257  {'batting': {'runs': 1, 'doubles': 0, 'triples...
# ID543135                    {'batting': {}, 'pitching': {}}
# ID600917  {'batting': {}, 'pitching': {'runs': 0, 'doubl...
# ID527048                    {'batting': {}, 'pitching': {}}
#
#                                                 seasonStats gameStatus  \
# ID641680  {'batting': {'runs': 2, 'doubles': 1, 'triples...         {}
# ID666142  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID669352  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID453178  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID641540  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID663993  {'batting': {'runs': 1, 'doubles': 0, 'triples...         {}
# ID608369  {'batting': {'runs': 2, 'doubles': 0, 'triples...         {}
# ID592351  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID543543  {'batting': {'runs': 1, 'doubles': 0, 'triples...         {}
# ID543760  {'batting': {'runs': 1, 'doubles': 0, 'triples...         {}
# ID673962  {'batting': {'runs': 1, 'doubles': 0, 'triples...         {}
# ID621368  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID677649  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID642546  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID594798  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID641598  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID608671  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID669701  {'batting': {'runs': 1, 'doubles': 0, 'triples...         {}
# ID571760  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID519293  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID666969  {'batting': {'runs': 1, 'doubles': 0, 'triples...         {}
# ID656271  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID543257  {'batting': {'runs': 1, 'doubles': 0, 'triples...         {}
# ID543135  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID600917  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
# ID527048  {'batting': {'runs': 0, 'doubles': 0, 'triples...         {}
#
#                                               allPositions
# ID641680                           [{'abbreviation': 'C'}]
# ID666142                           [{'abbreviation': 'P'}]
# ID669352  [{'abbreviation': 'PH'}, {'abbreviation': 'CF'}]
# ID453178                                               NaN
# ID641540                                               NaN
# ID663993                          [{'abbreviation': '1B'}]
# ID608369                          [{'abbreviation': 'SS'}]
# ID592351                                               NaN
# ID543543                          [{'abbreviation': 'DH'}]
# ID543760                          [{'abbreviation': '2B'}]
# ID673962                          [{'abbreviation': '3B'}]
# ID621368                                               NaN
# ID677649                                               NaN
# ID642546                           [{'abbreviation': 'P'}]
# ID594798                           [{'abbreviation': 'P'}]
# ID641598                                               NaN
# ID608671                                               NaN
# ID669701                          [{'abbreviation': 'LF'}]
# ID571760                                               NaN
# ID519293                                               NaN
# ID666969  [{'abbreviation': 'CF'}, {'abbreviation': 'RF'}]
# ID656271                           [{'abbreviation': 'P'}]
# ID543257  [{'abbreviation': 'RF'}, {'abbreviation': 'LF'}]
# ID543135                                               NaN
# ID600917                           [{'abbreviation': 'P'}]
# ID527048                                               NaN

# %%
schedule_to_date[schedule_to_date.venue_name=='Yankee Stadium']
# Out:
#     game_id         game_datetime   game_date game_type status  \
# 1    718781  2023-03-30T17:05:00Z  2023-03-30         R  Final
# 25   718762  2023-04-01T20:05:00Z  2023-04-01         R  Final
# 38   718747  2023-04-02T17:35:00Z  2023-04-02         R  Final
# 55   718725  2023-04-03T23:05:00Z  2023-04-03         R  Final
# 69   718710  2023-04-04T23:05:00Z  2023-04-04         R  Final
# 80   718699  2023-04-05T17:05:00Z  2023-04-05         R  Final
#
#                 away_name         home_name  away_id  home_id doubleheader  \
# 1    San Francisco Giants  New York Yankees      137      147            N
# 25   San Francisco Giants  New York Yankees      137      147            N
# 38   San Francisco Giants  New York Yankees      137      147            N
# 55  Philadelphia Phillies  New York Yankees      143      147            N
# 69  Philadelphia Phillies  New York Yankees      143      147            N
# 80  Philadelphia Phillies  New York Yankees      143      147            N
#
#     ...  venue_id      venue_name national_broadcasts    series_status  \
# 1   ...      3313  Yankee Stadium              [MLBN]    NYY leads 1-0
# 25  ...      3313  Yankee Stadium               [FOX]  Series tied 1-1
# 38  ...      3313  Yankee Stadium                  []     NYY wins 2-1
# 55  ...      3313  Yankee Stadium              [MLBN]    NYY leads 1-0
# 69  ...      3313  Yankee Stadium               [TBS]  Series tied 1-1
# 80  ...      3313  Yankee Stadium  [MLB.tv Free Game]     NYY wins 2-1
#
#              winning_team            losing_team  winning_pitcher  \
# 1        New York Yankees   San Francisco Giants      Gerrit Cole
# 25   San Francisco Giants       New York Yankees      Jakob Junis
# 38       New York Yankees   San Francisco Giants      Jhony Brito
# 55       New York Yankees  Philadelphia Phillies    Nestor Cortes
# 69  Philadelphia Phillies       New York Yankees  Andrew Bellatti
# 80       New York Yankees  Philadelphia Phillies      Gerrit Cole
#
#     losing_pitcher  save_pitcher  \
# 1       Logan Webb          None
# 25    Michael King  Camilo Doval
# 38  Ross Stripling          None
# 55  Taijuan Walker          None
# 69  Domingo German          None
# 80      Aaron Nola   Clay Holmes
#
#                                               summary
# 1   2023-03-30 - San Francisco Giants (0) @ New Yo...
# 25  2023-04-01 - San Francisco Giants (7) @ New Yo...
# 38  2023-04-02 - San Francisco Giants (0) @ New Yo...
# 55  2023-04-03 - Philadelphia Phillies (1) @ New Y...
# 69  2023-04-04 - Philadelphia Phillies (4) @ New Y...
# 80  2023-04-05 - Philadelphia Phillies (2) @ New Y...
#
# [6 rows x 29 columns]

# %%
statsapi.game_pace_data(season=2022)
# Out:
# {'copyright': 'Copyright 2023 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'teams': [],
#  'leagues': [],
#  'sports': [{'hitsPer9Inn': 16.58,
#    'runsPer9Inn': 8.7,
#    'pitchesPer9Inn': 296.08,
#    'plateAppearancesPer9Inn': 76.07,
#    'hitsPerGame': 16.33,
#    'runsPerGame': 8.57,
#    'inningsPlayedPerGame': 8.89,
#    'pitchesPerGame': 291.58,
#    'pitchersPerGame': 8.59,
#    'plateAppearancesPerGame': 74.92,
#    'totalGameTime': '7558:45:59',
#    'totalInningsPlayed': 21604.0,
#    'totalHits': 39675,
#    'totalRuns': 20817,
#    'totalPlateAppearances': 182052,
#    'totalPitchers': 20883,
#    'totalPitches': 708540,
#    'totalGames': 2430,
#    'total7InnGames': 10,
#    'total9InnGames': 2204,
#    'totalExtraInnGames': 216,
#    'timePerGame': '03:06:38',
#    'timePerPitch': '00:00:38',
#    'timePerHit': '00:11:25',
#    'timePerRun': '00:21:47',
#    'timePerPlateAppearance': '00:02:29',
#    'timePer9Inn': '03:09:30',
#    'timePer77PlateAppearances': '03:11:49',
#    'totalExtraInnTime': '786:24:59',
#    'timePer7InnGameWithoutExtraInn': '00:00:00',
#    'total9InnGamesCompletedEarly': 10,
#    'total9InnGamesWithoutExtraInn': 2204,
#    'total9InnGamesScheduled': 2430,
#    'hitsPerRun': 1.906,
#    'pitchesPerPitcher': 33.929,
#    'season': '2022',
#    'sport': {'id': 1, 'code': 'mlb', 'link': '/api/v1/sports/1'},
#    'prPortalCalculatedFields': {'total7InnGames': 10,
#     'total9InnGames': 2204,
#     'totalExtraInnGames': 216,
#     'timePer7InnGame': '02:15:24',
#     'timePer9InnGame': '03:03:45',
#     'timePerExtraInnGame': '03:38:26'}}]}
